# %% [markdown]
# ## Denoising Autoencoder transformation (encode-decode)
#
# Considering a dataset with $p$ numerical attributes.
#
# The goal of the autoencoder is to reduce the dimension of $p$ to $k$, such that these $k$ attributes are enough to recompose the original $p$ attributes. However from the $k$ dimensionals the data is returned back to $p$ dimensions. The higher the quality of autoencoder the similiar is the output from the input.

# %%
# DAL ToolBox
# version 1.1.727

source("https://raw.githubusercontent.com/cefet-rj-dal/daltoolbox/main/jupyter.R")

#loading DAL
load_library("daltoolbox")
load_library("ggplot2")
# Out:
# Loading required package: daltoolbox
#
# Registered S3 method overwritten by 'quantmod':
#   method            from
#   as.zoo.data.frame zoo
#
#
# Attaching package: ‘daltoolbox’
#
#
# The following object is masked from ‘package:base’:
#
#     transform
#
#
# Loading required package: ggplot2

# %% [markdown]
# ### dataset for example

# %%
data(sin_data)

sw_size <- 5
ts <- ts_data(sin_data$y, sw_size)

ts_head(ts)
# Out:
#      t4        t3        t2        t1        t0
# [1,] 0.0000000 0.2474040 0.4794255 0.6816388 0.8414710
# [2,] 0.2474040 0.4794255 0.6816388 0.8414710 0.9489846
# [3,] 0.4794255 0.6816388 0.8414710 0.9489846 0.9974950
# [4,] 0.6816388 0.8414710 0.9489846 0.9974950 0.9839859
# [5,] 0.8414710 0.9489846 0.9974950 0.9839859 0.9092974
# [6,] 0.9489846 0.9974950 0.9839859 0.9092974 0.7780732

# %% [markdown]
# ### applying data normalization

# %%
preproc <- ts_norm_gminmax()
preproc <- fit(preproc, ts)
ts <- transform(preproc, ts)

ts_head(ts)
# Out:
#      t4        t3        t2        t1        t0
# [1,] 0.5004502 0.6243512 0.7405486 0.8418178 0.9218625
# [2,] 0.6243512 0.7405486 0.8418178 0.9218625 0.9757058
# [3,] 0.7405486 0.8418178 0.9218625 0.9757058 1.0000000
# [4,] 0.8418178 0.9218625 0.9757058 1.0000000 0.9932346
# [5,] 0.9218625 0.9757058 1.0000000 0.9932346 0.9558303
# [6,] 0.9757058 1.0000000 0.9932346 0.9558303 0.8901126

# %% [markdown]
# ### spliting into training and test

# %%
samp <- ts_sample(ts, test_size = 10)
train <- as.data.frame(samp$train)
test <- as.data.frame(samp$test)

# %% [markdown]
# ### creating autoencoder
# Reduce from 5 to 3 dimensions

# %%
auto <- dns_encode_decode(5, 3)

auto <- fit(auto, train)

# %% [markdown]
# ### learning curves

# %%
train_loss <- unlist(auto$model$train_loss)
val_loss <- unlist(auto$model$val_loss)

fit_loss <- as.data.frame(cbind(train_loss, val_loss))
fit_loss['epoch'] <- 1:nrow(fit_loss)

ggplot(fit_loss, aes(x=epoch)) +
geom_line(aes(y=train_loss, colour='Train Loss')) +
geom_line(aes(y=val_loss, colour='Val Loss')) +
scale_color_manual(values=c('Blue','Orange')) +
theme_classic()
# Out:
# plot without title

# %% [markdown]
# ### testing autoencoder
# presenting the original test set and display encoding

# %%
print(head(test))
result <- transform(auto, test)
print(head(result))
# Out:
#          t4        t3        t2        t1        t0
# 1 0.7258342 0.8294719 0.9126527 0.9702046 0.9985496
# 2 0.8294719 0.9126527 0.9702046 0.9985496 0.9959251
# 3 0.9126527 0.9702046 0.9985496 0.9959251 0.9624944
# 4 0.9702046 0.9985496 0.9959251 0.9624944 0.9003360
# 5 0.9985496 0.9959251 0.9624944 0.9003360 0.8133146
# 6 0.9959251 0.9624944 0.9003360 0.8133146 0.7068409
#           [,1]      [,2]      [,3]      [,4]      [,5]
# [1,] 0.7858810 0.7971760 0.9276683 0.9310747 1.0176108
# [2,] 0.8910674 0.8847902 0.9867933 0.9457715 1.0154538
# [3,] 0.9733058 0.9479923 1.0111421 0.9433532 0.9837168
# [4,] 1.0236022 0.9777653 1.0009543 0.9231461 0.9263738
# [5,] 1.0496290 0.9757639 0.9573845 0.8716278 0.8337297
# [6,] 1.0458357 0.9448600 0.8889790 0.7927765 0.7275668

# %%
result <- as.data.frame(result)
names(result) <- names(test)
r2 <- c()
mape <- c()
for (col in names(test)){
r2_col <- cor(test[col], result[col])^2
r2 <- append(r2, r2_col)
mape_col <- mean((abs((result[col] - test[col]))/test[col])[[col]])
mape <- append(mape, mape_col)
print(paste(col, 'R2 test:', r2_col, 'MAPE:', mape_col))
}
print(paste('Means R2 test:', mean(r2), 'MAPE:', mean(mape)))
# Out:
# [1] "t4 R2 test: 0.993470765015842 MAPE: 0.0598664277769728"
# [1] "t3 R2 test: 0.993746095926252 MAPE: 0.0177670444712059"
# [1] "t2 R2 test: 0.997644112029182 MAPE: 0.0147870659150986"
# [1] "t1 R2 test: 0.99906724224775 MAPE: 0.030484400569346"
# [1] "t0 R2 test: 0.999918245204351 MAPE: 0.0357704656697144"
# [1] "Means R2 test: 0.996769292084675 MAPE: 0.0317350808804675"
